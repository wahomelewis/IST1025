# %% [markdown]
# <a href="https://colab.research.google.com/github/wahomelewis/IST1025/blob/main/Copy_of_671032_IST1025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]
unemployment_rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]

plt.plot(year, unemployment_rate)
plt.title('unemployment rate vs year')
plt.xlabel('year')
plt.ylabel('unemployment rate')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the 'tips' dataset directly from seaborn
tips = sns.load_dataset('tips')

# Prepare df for plotting
total_bill = tips['total_bill']
tip = tips['tip']
sex = tips['sex']
smoker = tips['smoker']

# Create a scatter plot
plt.figure(figsize=(10, 6))
colors = {'Male': 'blue', 'Female': 'red'}
smoker_markers = {'Yes': 'x', 'No': 'o'}

for i in range(len(total_bill)):
    plt.scatter(total_bill[i], tip[i], c=colors[sex[i]], marker=smoker_markers[smoker[i]], s=100)

# Set plot labels and title
plt.xlabel('Amount Due')
plt.ylabel('Gratuity')
plt.title('Scatter Plot of Amount Due vs. Gratuity')

# Add legend for gender and smoker status
for gender_label, color in colors.items():
    plt.scatter([], [], c=color, label=gender_label)
for smoker_label, marker in smoker_markers.items():
    plt.scatter([], [], marker=marker, label='Smoker: ' + smoker_label)

plt.legend(loc='upper right')

plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the 'tips' dataset directly from seaborn
tips = sns.load_dataset('tips')

# Assign the tips dataframe to the variable df
df = tips  # Assign 'tips' to 'df'

# Group the data by 'day' and calculate the average 'total_bill' for each day
average_total_bill_by_day = df.groupby('day')['total_bill'].mean()

# Create the bar plot
plt.bar(average_total_bill_by_day.index, average_total_bill_by_day.values)
plt.xlabel('Day of the Week')
plt.ylabel('Average Total Bill')
plt.title('Average Total Bill by Day of the Week')
plt.show()
# Out:
# <ipython-input-37-29eae150d2ca>:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_total_bill_by_day = df.groupby('day')['total_bill'].mean()

# %%
# Group the data by 'sex' and calculate the total count for each category
sex_counts = df['sex'].value_counts()

# Create the pie plot
plt.figure(figsize=(6, 6))
plt.pie(sex_counts, labels=sex_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sex')
plt.axis('equal')  # Equal aspect ratio ensures that the pie plot is circular.
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['total_bill'], kde=True)
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.title('Total Bill Histogram')
plt.show()

# %%
plt.figure(figsize=(8, 6))
# Replace 'A' and 'B' with actual column names from the 'tips' dataset
# For example, use 'total_bill' and 'tip'
sns.boxplot(data=df[['total_bill', 'tip']])
plt.title('Box Plot')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='day', y='total_bill', hue='sex', data=df, split=True, palette='muted')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill')
plt.title('Total Bill Distribution by Day and Sex')
plt.legend(title='Sex', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8, 6))
# Replace 'D' and 'A' with actual column names from the 'tips' dataset
# For example, use 'day' and 'total_bill' for x and y respectively.
sns.stripplot(data=df, x='day', y='total_bill', jitter=True)
plt.title('Strip Plot')
plt.show()

# %%
sns.pairplot(df, hue='day')  # Replace 'D' with 'day'
plt.title('Pair Plot')
plt.show()

# %%
# Distribution Plot
plt.figure(figsize=(8, 6))
# Replace 'A' with an actual column name from the 'tips' dataset
# For example, use 'total_bill'
sns.histplot(data=df, x='total_bill', kde=True)  # Changed 'A' to 'total_bill'
plt.title('Distribution Plot')
plt.show()

# %%
# Count Plot
plt.figure(figsize=(8, 6))
# Replace 'D' with an actual column name from the 'tips' dataset
# For example, use 'day' to count occurrences of each day
sns.countplot(data=df, x='day')  # Changed 'D' to 'day'
plt.title('Count Plot')
plt.show()

# %%
# Heatmap
# Select only numerical features for correlation
numerical_df = df.select_dtypes(include=['number'])
corr = numerical_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heat Map')
plt.show()
